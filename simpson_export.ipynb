# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

import ipywidgets as widgets
from ipywidgets import VBox,HBox, Layout

# %%
n=30
ub=4
lb=0

def f(x):
    return 3/(x+1)

def lefthand_approx(n,ub,lb):
    dx=(ub-lb)/n
    step_size=dx
    X=np.arange(lb,ub+step_size,step_size)
    xs=[]
    ys=[]
    for i in range(len(X)-1):
        x_i=[X[i],X[i+1],X[i+1],X[i],X[i]]
        y_i=[0,0,f(X[i]),f(X[i]),0]
        xs.extend(x_i)
        ys.extend(y_i)
    return xs,ys


def make_plot(n,ub,lb):
    #plt.clf()
    dx=(ub-lb)/n
    #X=np.arange(lb,ub+dx,dx)
    #step_size=0.1
    step_size=dx
    X=np.arange(lb,ub+step_size,step_size)

    plt.figure(figsize=(10,6))
    plt.subplot(2, 1, 1)

    xs,ys=lefthand_approx(n,ub,lb)
    plt.plot(xs, ys, color="red",label=f'$Lefthand$')

    plt.plot(X,f(X),label=r'$f(x)=\frac{3}{x+1}$')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    #plt.show()



def update_num_steps(change):
    #plt.clf()
    #return make_plot(change['new'],ub,lb)
    make_plot(change['new'],ub,lb)



def my_ui(_):

    style={'description_width':'200px'}
    layout={'description_width':'900px'}
    out=widgets.Output(layout=layout,style=style)
     

    slider=widgets.IntSlider(
                value=7,
                min=1,
                max=10,
                step=1,
                description='Num of Steps:',
                disabled=False,
                continuous_update=False,
                orientation='horizontal',
                readout=True,
                readout_format='d')

    slider.observe(update_num_steps,'value')

    UI=VBox([
        HBox([slider]),
        out])

    return UI


display(my_ui(_))

make_plot(n,ub,lb)
#plt.figure(figsize=(10,6))
#plt.subplot(2, 1, 1)
plt.show()

# %%
! jupyter nbconvert --to html --no-input simpson_export.ipynb
# Out:
# [NbConvertApp] Converting notebook simpson_export.ipynb to html
# [NbConvertApp] Writing 586918 bytes to simpson_export.html

# %% [markdown]
# <html><head>
#
#
# <!-- Load require.js. Delete this if your page already loads require.js -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" crossorigin="anonymous"></script>
# <script src="https://unpkg.com/@jupyter-widgets/html-manager@*/dist/embed-amd.js" crossorigin="anonymous"></script>
# <script type="application/vnd.jupyter.widget-state+json">
# {
#     "version_major": 2,
#     "version_minor": 0,
#     "state": {
#         "a488eab6dc62408a811fa4d8627944c3": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.2.0",
#             "state": {}
#         },
#         "0b8c77ac50dc4590b1f5d5431e1c065e": {
#             "model_name": "OutputModel",
#             "model_module": "@jupyter-widgets/output",
#             "model_module_version": "1.0.0",
#             "state": {
#                 "layout": "IPY_MODEL_a488eab6dc62408a811fa4d8627944c3"
#             }
#         },
#         "94594468257044dda0617c77ad61ffa3": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.2.0",
#             "state": {}
#         },
#         "f910660cea354bbc97888af71b96b1ba": {
#             "model_name": "SliderStyleModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.5.0",
#             "state": {
#                 "description_width": ""
#             }
#         },
#         "922de88740604512be4a4d8dc52c7b79": {
#             "model_name": "IntSliderModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.5.0",
#             "state": {
#                 "continuous_update": false,
#                 "description": "Num of Steps:",
#                 "layout": "IPY_MODEL_94594468257044dda0617c77ad61ffa3",
#                 "max": 10,
#                 "min": 1,
#                 "style": "IPY_MODEL_f910660cea354bbc97888af71b96b1ba",
#                 "value": 7
#             }
#         },
#         "5426c3d4081b4cc5bc99e386c9999f8f": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.2.0",
#             "state": {}
#         },
#         "7d415acd01894482a3ef444ab458a646": {
#             "model_name": "HBoxModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.5.0",
#             "state": {
#                 "children": [
#                     "IPY_MODEL_922de88740604512be4a4d8dc52c7b79"
#                 ],
#                 "layout": "IPY_MODEL_5426c3d4081b4cc5bc99e386c9999f8f"
#             }
#         },
#         "1bb5292772194575996622170c2f126f": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.2.0",
#             "state": {}
#         },
#         "5026a95d8813471db5585127f8751126": {
#             "model_name": "VBoxModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.5.0",
#             "state": {
#                 "children": [
#                     "IPY_MODEL_7d415acd01894482a3ef444ab458a646",
#                     "IPY_MODEL_0b8c77ac50dc4590b1f5d5431e1c065e"
#                 ],
#                 "layout": "IPY_MODEL_1bb5292772194575996622170c2f126f"
#             }
#         }
#     }
# }
# </script>
# </head>
# <body>
#
# <script type="application/vnd.jupyter.widget-view+json">
# {
#     "version_major": 2,
#     "version_minor": 0,
#     "model_id": "5026a95d8813471db5585127f8751126"
# }
# </script>
#
# </body>
# </html>
